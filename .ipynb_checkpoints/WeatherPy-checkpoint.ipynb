# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 603

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    
    # Time delay to ensure requests aren't maxed out
    time.sleep(2)
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city + "&units=metric"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isetskoye
# Processing Record 2 of Set 1 | nueve de julio
# Processing Record 3 of Set 1 | barcs
# Processing Record 4 of Set 1 | ust-nera
# Processing Record 5 of Set 1 | hammerfest
# Processing Record 6 of Set 1 | adamstown
# Processing Record 7 of Set 1 | kokstad
# Processing Record 8 of Set 1 | puerto natales
# Processing Record 9 of Set 1 | thal
# Processing Record 10 of Set 1 | khandyga
# Processing Record 11 of Set 1 | ponta delgada
# Processing Record 12 of Set 1 | port-aux-francais
# Processing Record 13 of Set 1 | yaren
# Processing Record 14 of Set 1 | waitangi
# Processing Record 15 of Set 1 | toliara
# Processing Record 16 of Set 1 | kill devil hills
# Processing Record 17 of Set 1 | ibiza
# Processing Record 18 of Set 1 | chhor
# Processing Record 19 of Set 1 | olonkinbyen
# Processing Record 20 of Set 1 | grytviken
# Processing Record 21 of Set 1 | puerto ayora
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          586
# Lat           586
# Lng           586
# Max Temp      586
# Humidity      586
# Cloudiness    586
# Wind Speed    586
# Country       586
# Date          586
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       isetskoye  56.4858   65.3226      7.68        69          94
# 1  nueve de julio -35.4444  -60.8831     12.76        99          99
# 2           barcs  45.9600   17.4586     15.76        65          90
# 3        ust-nera  64.5667  143.2000      1.94        86          39
# 4      hammerfest  70.6634   23.6821     -1.75        93          75
#
#    Wind Speed Country        Date
# 0        4.61      RU  1715033761
# 1        3.58      AR  1715033637
# 2        6.35      HU  1715033766
# 3        2.38      RU  1715033563
# 4        2.57      NO  1715033557

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             isetskoye  56.4858   65.3226      7.68        69          94
# 1        nueve de julio -35.4444  -60.8831     12.76        99          99
# 2                 barcs  45.9600   17.4586     15.76        65          90
# 3              ust-nera  64.5667  143.2000      1.94        86          39
# 4            hammerfest  70.6634   23.6821     -1.75        93          75
#
#          Wind Speed Country        Date
# City_ID
# 0              4.61      RU  1715033761
# 1              3.58      AR  1715033637
# 2              6.35      HU  1715033766
# 3              2.38      RU  1715033563
# 4              2.57      NO  1715033557

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df['Lat'],city_data_df['Max Temp'], marker="o",facecolors="purple",edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Latitude vs. Max Temperature")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df['Lat'],city_data_df['Humidity'], marker="o",facecolors="purple",edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Latitude vs. Humidity")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df['Lat'],city_data_df['Cloudiness'], marker="o",facecolors="purple",edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Latitude vs. Cloudiness")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df['Lat'],city_data_df['Wind Speed'], marker="o",facecolors="purple",edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Latitude vs. Wind Speed")
plt.grid()

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         isetskoye  56.4858   65.3226      7.68        69          94
# 2             barcs  45.9600   17.4586     15.76        65          90
# 3          ust-nera  64.5667  143.2000      1.94        86          39
# 4        hammerfest  70.6634   23.6821     -1.75        93          75
# 8              thal  35.4791   72.2439      6.36        51           0
#
#          Wind Speed Country        Date
# City_ID
# 0              4.61      RU  1715033761
# 2              6.35      HU  1715033766
# 3              2.38      RU  1715033563
# 4              2.57      NO  1715033557
# 8              3.71      PK  1715033778

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           nueve de julio -35.4444  -60.8831     12.76        99          99
# 5                adamstown -25.0660 -130.1015     21.94        78          47
# 6                  kokstad -30.5472   29.4241     13.76        40           0
# 7           puerto natales -51.7236  -72.4875     -0.90        90          18
# 11       port-aux-francais -49.3500   70.2167      6.37        98         100
#
#          Wind Speed Country        Date
# City_ID
# 1              3.58      AR  1715033637
# 5              8.12      PN  1715033555
# 6              2.17      ZA  1715033565
# 7              1.27      CL  1715033553
# 11            12.75      TF  1715033553

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
nh_xAxis = northern_hemi_df['Lat']
nh_yAxis = northern_hemi_df['Max Temp']
plt.scatter(nh_xAxis,nh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Lat vs. Max Temp in Northern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_xAxis, nh_yAxis)
regressVals = nh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(5.8,-5),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.8495287209345613

# %%
# Linear regression on Southern Hemisphere
sh_xAxis = southern_hemi_df['Lat']
sh_yAxis = southern_hemi_df['Max Temp']
plt.scatter(sh_xAxis,sh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.title("City Lat vs. Max Temp in Southern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_xAxis, sh_yAxis)
regressVals = sh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(-30,5),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.7997739259202576

# %% [markdown]
# **Discussion about the linear relationship:** The temperature and the latitude have a strong correlation to each other. The northern hemisphere has a negative correlation and the southern hemisphere has a positive correlation.  The closer the temperature gets to 0, the higher the temperature.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_xAxis = northern_hemi_df['Lat']
nh_yAxis = northern_hemi_df['Humidity']
plt.scatter(nh_xAxis,nh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Lat vs. Humidity in Northern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_xAxis, nh_yAxis)
regressVals = nh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(40,20),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.17968760442459306

# %%
# Southern Hemisphere
sh_xAxis = southern_hemi_df['Lat']
sh_yAxis = southern_hemi_df['Humidity']
plt.scatter(sh_xAxis,sh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.title("City Lat vs. Humidity in Southern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_xAxis, sh_yAxis)
regressVals = sh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(-25,40),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.08905763499777113

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no correlation between the humidity and latitude.  The latitude doesn't seem to have any affect on the humidity.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_xAxis = northern_hemi_df['Lat']
nh_yAxis = northern_hemi_df['Cloudiness']
plt.scatter(nh_xAxis,nh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Lat vs. Cloudiness in Northern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_xAxis, nh_yAxis)
regressVals = nh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(40,20),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.15582098746270123

# %%
# Southern Hemisphere
sh_xAxis = southern_hemi_df['Lat']
sh_yAxis = southern_hemi_df['Cloudiness']
plt.scatter(sh_xAxis,sh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.title("City Lat vs. Cloudiness in Southern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_xAxis, sh_yAxis)
regressVals = sh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(-45,30),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.05632669899043491

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no correlation between latitude and cloudiness.  The latitude doesn't seem to have any affect on cloudiness.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nh_xAxis = northern_hemi_df['Lat']
nh_yAxis = northern_hemi_df['Wind Speed']
plt.scatter(nh_xAxis,nh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Lat vs. Wind Speed in Northern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(nh_xAxis, nh_yAxis)
regressVals = nh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(nh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(40,10),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: 0.021201678465269276

# %%
# Southern Hemisphere
sh_xAxis = southern_hemi_df['Lat']
sh_yAxis = southern_hemi_df['Wind Speed']
plt.scatter(sh_xAxis,sh_yAxis, marker="o",facecolors="purple",edgecolors="black", alpha=0.75)
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.title("City Lat vs. Wind Speed in Southern Hemisphere")

(slope, intercept, rvalue, pvalue, stderr) = linregress(sh_xAxis, sh_yAxis)
regressVals = sh_xAxis * slope + intercept
lineEQ = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(sh_xAxis, regressVals, "r-")
plt.annotate(lineEQ,(-50,7),fontsize=15,color="red")
print(f"The r-value is: {rvalue}")
plt.show()
# Out:
# The r-value is: -0.09564762811743995

# %% [markdown]
# **Discussion about the linear relationship:** There is little to no correlation between latitude and wind speed.  The latitude doesn't seem to have any affect on wind speed.
